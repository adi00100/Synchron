# %% [markdown]
# ##### Creating a database connection

# %%
# %load_ext sql
user="postgres"
password="postgres"
database="synchron"
host="host.docker.internal"
connection=f"postgresql://{user}:{password}@{host}/{database}"
# %sql $connection

# %% [markdown]
# ##### List all tables in the connected database

# %%
# %sql SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';

# %% [markdown]
# ##### Create users

# %%
query="""
CREATE TABLE USERS(
  id VARCHAR(255) PRIMARY KEY NOT NULL, 
  fname VARCHAR(50) NOT NULL, 
  lname VARCHAR(50) NOT NULL, 
  email VARCHAR(255) UNIQUE NOT NULL,
  password VARCHAR(255) NOT NULL,
  role VARCHAR(10) NOT NULL
  )
"""
# %sql $query

# %% [markdown]
# ##### Create Sessions table

# %%
query="""
CREATE TABLE sessions(
  cookie VARCHAR(255) PRIMARY KEY NOT NULL, 
  user_id VARCHAR(255) NOT NULL,
  valid_till TIMESTAMP NOT NULL, 
  FOREIGN KEY(user_id) REFERENCES users(id) ON DELETE CASCADE
  );
"""
# %sql $query

# %% [markdown]
# ##### Create Teams table

# %%
# __fields_str__ = "id,name,scrum_master"
query="""
CREATE TABLE teams(
  id VARCHAR(255) PRIMARY KEY NOT NULL, 
  name VARCHAR(255) NOT NULL,
  scrum_master VARCHAR(255) NOT NULL,
  FOREIGN KEY(scrum_master) REFERENCES users(id) ON DELETE CASCADE
  );
"""
# %sql $query

# %% [markdown]
# ##### Create positions table

# %%
query="""
CREATE TABLE positions(
  id VARCHAR(255) PRIMARY KEY NOT NULL,
  name VARCHAR(255) UNIQUE NOT NULL
  );
"""
# %sql $query

# %% [markdown]
# ##### Create Members table

# %%
# __fields_str__ = "id,team_id,member_id,position"
# %sql DROP TABLE members
query=f"""
        CREATE TABLE members(
        id varchar(255) PRIMARY KEY NOT NULL,
        team_id varchar(255) NOT NULL,
        member_id varchar(255) NOT NULL,
        position varchar(255) NULL,

        FOREIGN KEY(team_id) REFERENCES teams(id),
        FOREIGN KEY(position) REFERENCES positions(id),
        UNIQUE(team_id,member_id)
    )
"""  
# %sql $query

# %% [markdown]
# ##### Standup card

# %%
query=f"""
    CREATE TABLE stand_up_cards(
        id varchar(255) PRIMARY KEY NOT NULL,
        team_id varchar(255) NOT NULL,
        date date NOT NULL,
        release_cycle varchar(255) NOT NULL,
        sprint_id varchar(255) NOT NULL,
        accomplished varchar(50),
        working_on varchar(50),
        blockers varchar(500) NOT NULL,
        extra_notes varchar(1000),

        FOREIGN KEY(team_id) REFERENCES teams(id) ON DELETE CASCADE
    )
"""
# %sql $query

# %% [markdown]
# ##### Create remarks table

# %%
query="""
    CREATE TABLE remarks(
    id varchar(255) PRIMARY KEY NOT NULL,
    card_id varchar(255) NOT NULL,
    member_id varchar(255) NOT NULL,
    notes varchar(1000) NOT NULL,

    FOREIGN KEY(card_id) REFERENCES  stand_up_cards(id) ON DELETE CASCADE,
    FOREIGN KEY(member_id) REFERENCES users(id) ON DELETE CASCADE,
    UNIQUE (card_id,member_id)
    )
"""
# %sql $query

# %% [markdown]
# # List all users

# %%
# %sql SELECT * FROM users
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# 38 rows affected.
# [('f0c11c06-09e4-11ee-b49d-e86a648f7f2f', 'Adithya', 'Pokharel', 'admin@admin.com', '$2b$12$IfwxTmD2.YYG7Px3EUpcLeaAJiGfBnzBT8LY./E/faDmTdd2uu3J.', 'admin'),
#  ('f1031889-09e4-11ee-a05c-e86a648f7f2f', 'Sita', 'Shrestha', 'sita.shrestha@example.com', '$2b$12$Ss1PGBWjwnJWYoTQSqmQ3.cEWSnXsNMHMvzmNP07jxEwzQ97XLMmC', 'DEV'),
#  ('f14e2cf5-09e4-11ee-9ddc-e86a648f7f2f', 'Hari', 'Gurung', 'hari.gurung@example.com', '$2b$12$mojvtzd1NPDYScakRivn7e9/N49EByI4vGGP56J2YOgi/bBPkcJMq', 'SM'),
#  ('f1d1fb59-09e4-11ee-a8da-e86a648f7f2f', 'Nisha', 'Rai', 'nisha.rai@example.com', '$2b$12$bqrNUaAiZWEeX9q9DfTfhOjOoKfAEnfmPcTnom8JcE04c2KMNsTLq', 'SM'),
#  ('f2378d15-09e4-11ee-a803-e86a648f7f2f', 'Rajesh', 'Thapa', 'rajesh.thapa@example.com', '$2b$12$DJcnUEV8i9HplcG2bRUxSOIjaLh94Rtu5BRXZlr972oMJeKarkZg6', 'DEV'),
#  ('f292e61b-09e4-11ee-b1cc-e86a648f7f2f', 'Meera', 'Lama', 'meera.lama@example.com', '$2b$12$VHzktrCrU8ljTKEfZLpvdOT1H6IvZ9b.1vL.wCh0WcJ/JkyZ4knHS', 'SM'),
#  ('f2ddc5c0-09e4-11ee-b733-e86a648f7f2f', 'Binod', 'Rajbanshi', 'binod.rajbanshi@example.com', '$2b$12$oOvOoXQ8lk95x.eJds.k3OMNUeqO7FrRMeF1s8dzVyDCY1fWQ9x1G', 'DEV'),
#  ('f3155add-09e4-11ee-b80b-e86a648f7f2f', 'Asha', 'Pandey', 'asha.pandey@example.com', '$2b$12$PZmn2Hkx75XAIizYBF2zGuld4gvumeFHA5W5uTZKge.Vdw1aMAQJi', 'SM'),
#  ('f350c53c-09e4-11ee-8e68-e86a648f7f2f', 'Kamal', 'Bhattarai', 'kamal.bhattarai@example.com', '$2b$12$jb7.2SeYZXtjMmLZL7jIlujKIh5HiINERzEl9VVvy4j0rHIDbFad2', 'SM'),
#  ('f3953b96-09e4-11ee-a60c-e86a648f7f2f', 'Anita', 'Rana', 'anita.rana@example.com', '$2b$12$bV1YHTIEisDm9TwGT6p8eOwbNGyhQUo8wZe0d/lnLtFS7zKgIWhDm', 'SM'),
#  ('f3d0f941-09e4-11ee-a4a6-e86a648f7f2f', 'Ramesh', 'Dhakal', 'ramesh.dhakal@example.com', '$2b$12$6cubYnKMOiYGwYY/lBB5eutOP5NixiJB.YmDuWVZmc5QEPyj.pFmC', 'DEV'),
#  ('f40ef769-09e4-11ee-8bf8-e86a648f7f2f', 'Nina', 'Joshi', 'nina.joshi@example.com', '$2b$12$OLxVK6yqoCZHhuMNUIlUqu4HC2Q5wPPWtTxlfWo0VDDkDboTNWty2', 'SM'),
#  ('f451264f-09e4-11ee-9946-e86a648f7f2f', 'Santosh', 'Rai', 'santosh.rai@example.com', '$2b$12$o0BfgRSSiRVOdq6FPFrSce9VHRnvlyXxM3OiEvNLQF0O1Crf.27G6', 'DEV'),
#  ('f48ccce7-09e4-11ee-bd43-e86a648f7f2f', 'Saraswati', 'Thapa', 'saraswati.thapa@example.com', '$2b$12$v.66SN7vGIzg5HFU54y7xuObh7g0ZO0r0p9mQdkDcaSNJ81ljJpLG', 'SM'),
#  ('f4c8ef12-09e4-11ee-a0eb-e86a648f7f2f', 'Ganesh', 'Basnet', 'ganesh.basnet@example.com', '$2b$12$FcvCL9Ru/SXAmEkfK33pXu0VULA8aFnjuf/zV3fCsku4tWDKOSG32', 'DEV'),
#  ('f4fd1e05-09e4-11ee-b83d-e86a648f7f2f', 'Indira', 'Acharya', 'indira.acharya@example.com', '$2b$12$S9AO6oqChkmHRLTk5XUKcuxIb1xyulpXlARmUrLYxMZph/u.S.7zq', 'SM'),
#  ('f532d1e9-09e4-11ee-bb87-e86a648f7f2f', 'Prakash', 'Rijal', 'prakash.rijal@example.com', '$2b$12$nnE.OIUYLlZfwxPSLUMcOOYObT6ReJ4YVs27rgmYNjKCaFFjoVM4K', 'DEV'),
#  ('f56b5dff-09e4-11ee-bd81-e86a648f7f2f', 'Mira', 'Sharma', 'mira.sharma@example.com', '$2b$12$xc9T8.dzOXuXI9XsyaQaB.cDnekUk.AJw3xbl6iBRN6qzu0E5QOwO', 'SM'),
#  ('f5ab6fb0-09e4-11ee-b663-e86a648f7f2f', 'Rajan', 'Pokharel', 'rajan.pokharel@example.com', '$2b$12$aoTqX79Du3T8rwJVAvMkOOECgG7fG8cmtXl0YNCXw5Y5hB1OMd712', 'DEV'),
#  ('f5e6c058-09e4-11ee-9ffd-e86a648f7f2f', 'Sunita', 'Karki', 'sunita.karki@example.com', '$2b$12$LOvNq66IW0R3Q6ZqWE1T2exTea0wl2GmtnYrKee54Q/Uql4gNG5xW', 'SM'),
#  ('f619ffe6-09e4-11ee-bfdc-e86a648f7f2f', 'Amit', 'Giri', 'amit.giri@example.com', '$2b$12$g/rF/KNrtM18sKv2YljYFe2WUvNpE6KicyIGNBfiJjq20v5CNyH7S', 'DEV'),
#  ('f650a2a5-09e4-11ee-9132-e86a648f7f2f', 'Nisha', 'Maharjan', 'nisha.maharjan@example.com', '$2b$12$I8Gck6Txurx3lgXSr11AhuTviwToN7F5.PZmsX4vEUnZklsnDSQ/G', 'SM'),
#  ('f686c16c-09e4-11ee-9881-e86a648f7f2f', 'Bikash', 'Dongol', 'bikash.dongol@example.com', '$2b$12$9kdLRoYTIn1niMbLCd6mC.TvcjxQyFlmvedCvdM6FNr7ykASoKr.6', 'DEV'),
#  ('f6c038be-09e4-11ee-aea1-e86a648f7f2f', 'Anita', 'Bista', 'anita.bista@example.com', '$2b$12$XhnqD6zNB.DVx7G01mdYbOd9dryid/spjXZk9xUyp.Jlei4W1IqyC', 'DEV'),
#  ('f6f58698-09e4-11ee-8bb1-e86a648f7f2f', 'Sanjay', 'Malla', 'sanjay.malla@example.com', '$2b$12$aCOXhlLuHk6sGyIzbOJq1eysZPowBDylC8IprZpQkp06HDJy7GK0C', 'DEV'),
#  ('f72e3107-09e4-11ee-bf7e-e86a648f7f2f', 'Rina', 'Koirala', 'rina.koirala@example.com', '$2b$12$FBNhBGYWEZB.Qu9eRd1JE.s1km87shiYmaouzfJJHNWVpFGZrFU5O', 'DEV'),
#  ('f764838e-09e4-11ee-853f-e86a648f7f2f', 'Manoj', 'Shakya', 'manoj.shakya@example.com', '$2b$12$V8JxyZOEk326Jth.0B.QMOMRQnhaKfizNRnE1eSGgX8g.V0KUUXiW', 'DEV'),
#  ('f79b1716-09e4-11ee-aa0f-e86a648f7f2f', 'Neha', 'Tamang', 'neha.tamang@example.com', '$2b$12$np1eCjBeSpg0RWAajx6mROhaFSLeuyFNJbbTrbPMaOppikjPuwT3S', 'DEV'),
#  ('f7cff578-09e4-11ee-8000-e86a648f7f2f', 'Dinesh', 'Pradhan', 'dinesh.pradhan@example.com', '$2b$12$3g6HVH4avgbUnBWCmaSCQO4cFfSIqjglEo3itFGDcSULL3zwMtct6', 'DEV'),
#  ('f80151d7-09e4-11ee-9ed6-e86a648f7f2f', 'Sarita', 'Rai', 'sarita.rai@example.com', '$2b$12$YEOl1Iqof40qm49IFRQkbOW0vSwFFWNBbuLxZtsh2aKipGpTJoxbu', 'DEV'),
#  ('f83d13a8-09e4-11ee-a61f-e86a648f7f2f', 'Sabin', 'Khadka', 'sabin.khadka@example.com', '$2b$12$ndJq8QWd7lJyaIEvceo53.U3Qq.g6qz7sPi.baAMCSJIjvr/PgZpq', 'DEV'),
#  ('f87d0a31-09e4-11ee-9873-e86a648f7f2f', 'Laxmi', 'Paudel', 'laxmi.paudel@example.com', '$2b$12$yjzM4jzyLwQopk9rsmnkwuo1A394U9S/55/DFjWfSPi9MmdrPicaS', 'DEV'),
#  ('f8bd1678-09e4-11ee-a39a-e86a648f7f2f', 'Nabin', 'Dhakal', 'nabin.dhakal@example.com', '$2b$12$80qgkIdl/2VC2BsNzA5gCetQPTW2coKfvNcNOoJMY./AD2f9xicGS', 'DEV'),
#  ('f8f76fe4-09e4-11ee-852f-e86a648f7f2f', 'Shanti', 'Ghimire', 'shanti.ghimire@example.com', '$2b$12$84nTlhFoAuBoJsyhWXkOqu8KU2pTQR.4Y81o2dRRxJ7SvxSXNXzMa', 'DEV'),
#  ('f92dbf33-09e4-11ee-ab0a-e86a648f7f2f', 'Rajeshwari', 'Gurung', 'rajeshwari.gurung@example.com', '$2b$12$f2RI6vkiN7xcwOoW6VHKYuUcOa.Oh0j423e20W7MbRpNaPE8w43G6', 'DEV'),
#  ('f961f587-09e4-11ee-9990-e86a648f7f2f', 'Kiran', 'Bhandari', 'kiran.bhandari@example.com', '$2b$12$F25xJ/yc80xDlwMzViajFesvRsunrUzOmzdNf6gNwjbJVwVCdKMjq', 'DEV'),
#  ('f99c01c7-09e4-11ee-9801-e86a648f7f2f', 'Samir', 'Rai', 'samir.rai@example.com', '$2b$12$lXhf0fR.bsPu2CYgoN35/eO1SRm93qBtNGCpcbA4kML/8xTKWaVCu', 'DEV'),
#  ('f9d26f31-09e4-11ee-8b76-e86a648f7f2f', 'Anju', 'Thapa', 'anju.thapa@example.com', '$2b$12$ZQwMe84I4e.zUtxde7O7Ie8LEPKeq2TcwSJfYkjdrXS7OsLk0.x9m', 'SM')]

# %% [markdown]
# # List sessions

# %%
# %sql SELECT * FROM sessions
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# 0 rows affected.
# []

# %% [markdown]
# # List all teams

# %%
# %sql SELECT * FROM teams
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# 5 rows affected.
# [('91a02123-09e5-11ee-be43-e86a648f7f2f', 'Falcon', 'f14e2cf5-09e4-11ee-9ddc-e86a648f7f2f'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'Phoenix', 'f1d1fb59-09e4-11ee-a8da-e86a648f7f2f'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'Cobalt', 'f292e61b-09e4-11ee-b1cc-e86a648f7f2f'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'Nebula', 'f3155add-09e4-11ee-b80b-e86a648f7f2f'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'Zenith', 'f350c53c-09e4-11ee-8e68-e86a648f7f2f')]

# %% [markdown]
# # List the scrum master of all teams

# %%
query="""
    SELECT teams.id as team_id,users.id as user_id,teams.name,users.fname,users.lname,email,'SM' as role 
    FROM teams JOIN users ON teams.scrum_master=users.id
"""
# %sql $query
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# 5 rows affected.
# [('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f14e2cf5-09e4-11ee-9ddc-e86a648f7f2f', 'Falcon', 'Hari', 'Gurung', 'hari.gurung@example.com', 'SM'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f1d1fb59-09e4-11ee-a8da-e86a648f7f2f', 'Phoenix', 'Nisha', 'Rai', 'nisha.rai@example.com', 'SM'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f292e61b-09e4-11ee-b1cc-e86a648f7f2f', 'Cobalt', 'Meera', 'Lama', 'meera.lama@example.com', 'SM'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f3155add-09e4-11ee-b80b-e86a648f7f2f', 'Nebula', 'Asha', 'Pandey', 'asha.pandey@example.com', 'SM'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f350c53c-09e4-11ee-8e68-e86a648f7f2f', 'Zenith', 'Kamal', 'Bhattarai', 'kamal.bhattarai@example.com', 'SM')]

# %%
query="""
    SELECT teams.id as team_id,users.id as user_id,teams.name as team_name,users.fname as fname,users.lname as lname,users.email as email,'DEV' as role  FROM 
    teams JOIN members ON teams.id=members.team_id
    JOIN users ON members.member_id=users.id

    """
# %sql $query
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# 42 rows affected.
# [('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f2378d15-09e4-11ee-a803-e86a648f7f2f', 'Nebula', 'Rajesh', 'Thapa', 'rajesh.thapa@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f2ddc5c0-09e4-11ee-b733-e86a648f7f2f', 'Zenith', 'Binod', 'Rajbanshi', 'binod.rajbanshi@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f2ddc5c0-09e4-11ee-b733-e86a648f7f2f', 'Falcon', 'Binod', 'Rajbanshi', 'binod.rajbanshi@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f3d0f941-09e4-11ee-a4a6-e86a648f7f2f', 'Nebula', 'Ramesh', 'Dhakal', 'ramesh.dhakal@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f3d0f941-09e4-11ee-a4a6-e86a648f7f2f', 'Cobalt', 'Ramesh', 'Dhakal', 'ramesh.dhakal@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f451264f-09e4-11ee-9946-e86a648f7f2f', 'Zenith', 'Santosh', 'Rai', 'santosh.rai@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f451264f-09e4-11ee-9946-e86a648f7f2f', 'Falcon', 'Santosh', 'Rai', 'santosh.rai@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f4c8ef12-09e4-11ee-a0eb-e86a648f7f2f', 'Cobalt', 'Ganesh', 'Basnet', 'ganesh.basnet@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f4c8ef12-09e4-11ee-a0eb-e86a648f7f2f', 'Falcon', 'Ganesh', 'Basnet', 'ganesh.basnet@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f532d1e9-09e4-11ee-bb87-e86a648f7f2f', 'Phoenix', 'Prakash', 'Rijal', 'prakash.rijal@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f532d1e9-09e4-11ee-bb87-e86a648f7f2f', 'Falcon', 'Prakash', 'Rijal', 'prakash.rijal@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f5ab6fb0-09e4-11ee-b663-e86a648f7f2f', 'Cobalt', 'Rajan', 'Pokharel', 'rajan.pokharel@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f619ffe6-09e4-11ee-bfdc-e86a648f7f2f', 'Zenith', 'Amit', 'Giri', 'amit.giri@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f619ffe6-09e4-11ee-bfdc-e86a648f7f2f', 'Nebula', 'Amit', 'Giri', 'amit.giri@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f619ffe6-09e4-11ee-bfdc-e86a648f7f2f', 'Phoenix', 'Amit', 'Giri', 'amit.giri@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f686c16c-09e4-11ee-9881-e86a648f7f2f', 'Zenith', 'Bikash', 'Dongol', 'bikash.dongol@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f686c16c-09e4-11ee-9881-e86a648f7f2f', 'Cobalt', 'Bikash', 'Dongol', 'bikash.dongol@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f6f58698-09e4-11ee-8bb1-e86a648f7f2f', 'Nebula', 'Sanjay', 'Malla', 'sanjay.malla@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f6f58698-09e4-11ee-8bb1-e86a648f7f2f', 'Phoenix', 'Sanjay', 'Malla', 'sanjay.malla@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f72e3107-09e4-11ee-bf7e-e86a648f7f2f', 'Zenith', 'Rina', 'Koirala', 'rina.koirala@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f72e3107-09e4-11ee-bf7e-e86a648f7f2f', 'Phoenix', 'Rina', 'Koirala', 'rina.koirala@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f764838e-09e4-11ee-853f-e86a648f7f2f', 'Nebula', 'Manoj', 'Shakya', 'manoj.shakya@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f79b1716-09e4-11ee-aa0f-e86a648f7f2f', 'Zenith', 'Neha', 'Tamang', 'neha.tamang@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f79b1716-09e4-11ee-aa0f-e86a648f7f2f', 'Nebula', 'Neha', 'Tamang', 'neha.tamang@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f7cff578-09e4-11ee-8000-e86a648f7f2f', 'Cobalt', 'Dinesh', 'Pradhan', 'dinesh.pradhan@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f80151d7-09e4-11ee-9ed6-e86a648f7f2f', 'Phoenix', 'Sarita', 'Rai', 'sarita.rai@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f83d13a8-09e4-11ee-a61f-e86a648f7f2f', 'Nebula', 'Sabin', 'Khadka', 'sabin.khadka@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f83d13a8-09e4-11ee-a61f-e86a648f7f2f', 'Cobalt', 'Sabin', 'Khadka', 'sabin.khadka@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f83d13a8-09e4-11ee-a61f-e86a648f7f2f', 'Falcon', 'Sabin', 'Khadka', 'sabin.khadka@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f87d0a31-09e4-11ee-9873-e86a648f7f2f', 'Cobalt', 'Laxmi', 'Paudel', 'laxmi.paudel@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f87d0a31-09e4-11ee-9873-e86a648f7f2f', 'Phoenix', 'Laxmi', 'Paudel', 'laxmi.paudel@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f87d0a31-09e4-11ee-9873-e86a648f7f2f', 'Falcon', 'Laxmi', 'Paudel', 'laxmi.paudel@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f8bd1678-09e4-11ee-a39a-e86a648f7f2f', 'Phoenix', 'Nabin', 'Dhakal', 'nabin.dhakal@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f8f76fe4-09e4-11ee-852f-e86a648f7f2f', 'Zenith', 'Shanti', 'Ghimire', 'shanti.ghimire@example.com', 'DEV'),
#  ('91a02123-09e5-11ee-be43-e86a648f7f2f', 'f8f76fe4-09e4-11ee-852f-e86a648f7f2f', 'Falcon', 'Shanti', 'Ghimire', 'shanti.ghimire@example.com', 'DEV'),
#  ('91a37c58-09e5-11ee-b7e7-e86a648f7f2f', 'f92dbf33-09e4-11ee-ab0a-e86a648f7f2f', 'Nebula', 'Rajeshwari', 'Gurung', 'rajeshwari.gurung@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f92dbf33-09e4-11ee-ab0a-e86a648f7f2f', 'Cobalt', 'Rajeshwari', 'Gurung', 'rajeshwari.gurung@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f92dbf33-09e4-11ee-ab0a-e86a648f7f2f', 'Phoenix', 'Rajeshwari', 'Gurung', 'rajeshwari.gurung@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f961f587-09e4-11ee-9990-e86a648f7f2f', 'Zenith', 'Kiran', 'Bhandari', 'kiran.bhandari@example.com', 'DEV'),
#  ('91a292b3-09e5-11ee-8245-e86a648f7f2f', 'f961f587-09e4-11ee-9990-e86a648f7f2f', 'Cobalt', 'Kiran', 'Bhandari', 'kiran.bhandari@example.com', 'DEV'),
#  ('91a18bcc-09e5-11ee-84cb-e86a648f7f2f', 'f961f587-09e4-11ee-9990-e86a648f7f2f', 'Phoenix', 'Kiran', 'Bhandari', 'kiran.bhandari@example.com', 'DEV'),
#  ('91a4542b-09e5-11ee-9a89-e86a648f7f2f', 'f99c01c7-09e4-11ee-9801-e86a648f7f2f', 'Zenith', 'Samir', 'Rai', 'samir.rai@example.com', 'DEV')]

# %% [markdown]
# Adithya,Pokharel,admin@admin.com,admin
# Nisha,Rai,nisha.rai@example.com,nisha789,SM
# Prakash,Rijal,prakash.rijal@example.com,prakash2023,DEV

# %%
# %sql TRUNCATE sessions
# Out:
#  * postgresql://postgres:***@host.docker.internal/synchron
# Done.
# []

# %%
# %sql INSERT INTO stand_up_cards INTO VALUES
